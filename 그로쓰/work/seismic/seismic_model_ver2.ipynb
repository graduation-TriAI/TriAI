# %% [markdown]
# ### 구글 드라이브 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 라이브러리 import

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.48)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.8.0-py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 35.7 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.8.0

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import pandas as pd
from torch.utils.data import Dataset, DataLoader, random_split, WeightedRandomSampler
from tqdm.notebook import tqdm
import copy
import random
import optuna

# %% [markdown]
# ### 데이터셋 로드

# %%
pgv_path = '/content/drive/MyDrive/TriAI/그로쓰/Data/processed/pgv/tohoku/processed_pgv_data2.csv'
seismic_path = '/content/drive/MyDrive/TriAI/그로쓰/Data/processed/seismic/tohoku/tohoku_dataset_ver2.npz'

BATCH_SIZE = 2
NUM_EPOCHS = 100
LEARNING_RATE = 0.001

# %%
class Dataset(Dataset):
    def __init__(self, pgv_path, seismic_path, is_train=True):
        seismic_data = np.load(seismic_path, allow_pickle=True)
        self.seismic = seismic_data['data']
        self.station_names = seismic_data['station_names']
        pgv_data = pd.read_csv(pgv_path)
        self.pgv_dict = dict(zip(
            pgv_data['station'].astype(str).str.strip(),
            pgv_data['pgv']
        ))
        self.is_train = is_train

    def __len__(self):
        return len(self.seismic)

    def __getitem__(self, idx):
        seismic = np.copy(self.seismic[idx])
        station_name = str(self.station_names[idx]).strip()

        # 로그 스케일링
        raw_pgv = self.pgv_dict.get(station_name, 0.0)
        pgv_label = np.log1p(raw_pgv)

        # Data Augmentation
        if self.is_train:
            # Scale Amplitude
            if random.random() < 0.3:
                scale_factor = random.uniform(0.5, 2.0)
                seismic *= scale_factor

            # Drop Channel
            if random.random() < 0.2:
                c1, c2, c3 = random.choice([0, 1]), random.choice([0, 1]), random.choice([0, 1])
                if c1 + c2 + c3 > 0:
                    if c1 == 0: seismic[:, :, 0] = 0
                    if c2 == 0: seismic[:, :, 1] = 0
                    if c3 == 0: seismic[:, :, 2] = 0

            # Add Gaussian Noise
            if random.random() < 0.3:
                for w in range(8):
                    for ch in range(3):
                        noise_amp = random.uniform(0.01, 0.15) * np.max(np.abs(seismic[w, :, ch]) + 1e-8)
                        seismic[w, :, ch] += np.random.normal(0, noise_amp, seismic.shape[1])

        seismic = np.transpose(seismic, (0, 2, 1))

        # 정규화
        seismic = seismic.astype(np.float32)
        mean = np.mean(seismic, axis=-1, keepdims=True)
        std = np.std(seismic, axis=-1, keepdims=True)
        seismic = (seismic - mean) / (std + 1e-8)

        x_tensor = torch.tensor(seismic, dtype=torch.float32)
        y_tensor = torch.tensor([pgv_label], dtype=torch.float32)

        return x_tensor, y_tensor

# %% [markdown]
# ### Seismic model

# %%
class ResNetBlock(nn.Module):
    def __init__(self, filters, kernel_size, drop_rate):
        super(ResNetBlock, self).__init__()
        padding = kernel_size // 2

        self.bn1 = nn.BatchNorm1d(filters)
        self.drop1 = nn.Dropout1d(drop_rate)
        self.conv1 = nn.Conv1d(filters, filters, kernel_size, padding=padding)

        self.bn2 = nn.BatchNorm1d(filters)
        self.drop2 = nn.Dropout1d(drop_rate)
        self.conv2 = nn.Conv1d(filters, filters, kernel_size, padding=padding)

    def forward(self, x):
        res = x
        # 첫 번째 레이어
        out = self.bn1(x)
        out = F.relu(out)
        out = self.drop1(out)
        out = self.conv1(out)
        # 두 번째 레이어
        out = self.bn2(out)
        out = F.relu(out)
        out = self.drop2(out)
        out = self.conv2(out)
        # 잔차 연결 (Add)
        return out + res


class BiLSTMBlock(nn.Module):
    def __init__(self, in_channels, filters, drop_rate):
        super(BiLSTMBlock, self).__init__()
        self.drop_rate = drop_rate
        self.bilstm = nn.LSTM(input_size=in_channels, hidden_size=filters,
                              num_layers=1, batch_first=True, bidirectional=True)
        self.nin = nn.Conv1d(filters * 2, filters, kernel_size=1)
        self.bn = nn.BatchNorm1d(filters)

    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = F.dropout(x, p=self.drop_rate, training=self.training)

        out, _ = self.bilstm(x)

        out = out.permute(0, 2, 1)
        out = self.nin(out)
        out = self.bn(out)
        return out


class EQTEncoder(nn.Module):
    def __init__(self, drop_rate=0.1, output_dim=128):
        super(EQTEncoder, self).__init__()

        filters = [8, 16, 16, 32, 32, 96, 96]
        kernels = [11, 9, 7, 7, 5, 5, 3]

        # Conv
        self.encoder_convs = nn.ModuleList()
        in_c = 3
        for out_c, k in zip(filters, kernels):
            self.encoder_convs.append(nn.Sequential(
                nn.Conv1d(in_c, out_c, kernel_size=k, padding=k//2),
                nn.ReLU(),
                nn.MaxPool1d(2)
            ))
            in_c = out_c

        # ResCNN
        self.resnet_blocks = nn.ModuleList()
        for cb in range(5):
            self.resnet_blocks.append(ResNetBlock(96, kernel_size=3, drop_rate=drop_rate))
            if cb > 2:
                self.resnet_blocks.append(ResNetBlock(96, kernel_size=3, drop_rate=drop_rate))

        # Bi-LSTM / NiN
        self.bilstm_blocks = nn.ModuleList()
        lstm_in_c = 96
        for _ in range(3):
            self.bilstm_blocks.append(BiLSTMBlock(in_channels=lstm_in_c, filters=16, drop_rate=drop_rate))
            lstm_in_c = 16

        # Transformer
        encoder_layer = nn.TransformerEncoderLayer(d_model=16, nhead=2, dim_feedforward=128,
                                                   dropout=drop_rate, batch_first=True)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=2)

        # 특징맵 차원 조정
        self.final_projection = nn.Linear(16, output_dim)

    def forward(self, x):
        for conv in self.encoder_convs:
            x = conv(x)
        for resnet in self.resnet_blocks:
            x = resnet(x)
        for bilstm in self.bilstm_blocks:
            x = bilstm(x)
        x = x.permute(0, 2, 1)
        x = self.transformer(x)

        feature_map = self.final_projection(x)

        return feature_map


class Decoder(nn.Module):
	def __init__(self, input_dim=128, hidden_dim=64, output_dim=1):
		super(Decoder, self).__init__()

		# 1. Attention Pooling
		self.attention = nn.Linear(input_dim, 1)

		# 2. MLP
		self.mlp = nn.Sequential(
			nn.Linear(input_dim, hidden_dim),
			nn.BatchNorm1d(hidden_dim),
			nn.ReLU(),
			nn.Dropout(0.3)
		)

		# 3. Regression
		self.regression = nn.Linear(hidden_dim, output_dim)

	def forward(self, x):

		# 1. Attention Pooling
		scores = self.attention(x).squeeze(-1)
		weights = F.softmax(scores, dim=1).unsqueeze(-1)

		context = torch.sum(x * weights, dim=1)

		# 2. MLP
		features = self.mlp(context)

		# 3. Regression
		output = self.regression(features)

		return output

# %%
class FullEQTModel(nn.Module):
    def __init__(self):
        super(FullEQTModel, self).__init__()
        self.encoder = EQTEncoder(output_dim=128)
        self.decoder = Decoder(input_dim=128)

    def forward(self, x):
        batch_size, num_windows, channels, time = x.shape

        # 인코더 통과를 위해 batch와 window 차원을 합침
        x = x.view(batch_size * num_windows, channels, time)
        features = self.encoder(x)

        # 추출된 특징을 다시 관측소별로 모아 하나의 시퀀스로 flatten
        seq_len = features.shape[1]
        features = features.view(batch_size, num_windows * seq_len, 128)

        output = self.decoder(features)
        return output

# %% [markdown]
# ### Training

# %%
def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    full_dataset = Dataset(pgv_path, seismic_path, is_train=False)

    total_size = len(full_dataset)
    train_size = int(total_size * 0.8)
    val_size = total_size - train_size
    train_subset, val_subset = random_split(full_dataset, [train_size, val_size])

    # Train dataset에만 is_train=True를 강제 적용
    train_subset.dataset.is_train = True
    val_subset.dataset.is_train = False

    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False)

    model = FullEQTModel().to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # 지정된 에폭(20, 40, 60, 90)을 통과할 때마다 학습률에 gamma(0.1)를 곱해 감소
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20, 40, 60, 90], gamma=0.1)

    best_val_loss = float('inf')
    best_model_weights = None

    print("=========================== Train ===========================")

    for epoch in range(NUM_EPOCHS):
        # Train
        model.train()
        train_loss = 0.0

        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        avg_train_loss = train_loss / len(train_loader)

        # Validation
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                val_loss += loss.item()

        avg_val_loss = val_loss / len(val_loader)

        # 1에폭이 끝날 때마다 스케줄러 업데이트
        scheduler.step()
        current_lr = optimizer.param_groups[0]['lr']

        # 로그 스케일링된 MSE에서 원래 PGV 스케일의 RMSE로 복원하여 출력
        val_rmse_original_scale = np.expm1(avg_val_loss ** 0.5)

        # 최고 성능 갱신 시 모델 자동 저장
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_model_weights = copy.deepcopy(model.state_dict())

        print(f"Epoch [{epoch+1}/{NUM_EPOCHS}] LR: {current_lr:.8f} | "
              f"Train Loss: {avg_train_loss:.4f} | "
              f"Val Loss: {avg_val_loss:.4f} (Original PGV RMSE: {val_rmse_original_scale:.2f})")

    # 최고 성능 모델 파일로 추출
    torch.save(best_model_weights, 'best_seismic_model.pth')

    # 메모리 상의 모델도 최고 성능 모델로 저장
    model.load_state_dict(best_model_weights)
    return model

if __name__ == '__main__':
    best_model = main()
# Out:
# =========================== Train ===========================
# Epoch [1/100] LR: 0.00100000 | Train Loss: 5.0487 | Val Loss: 5.2742 (Original PGV RMSE: 8.94)
# Epoch [2/100] LR: 0.00100000 | Train Loss: 1.6421 | Val Loss: 15.5827 (Original PGV RMSE: 50.81)
# Epoch [3/100] LR: 0.00100000 | Train Loss: 0.8236 | Val Loss: 4.4778 (Original PGV RMSE: 7.30)
# Epoch [4/100] LR: 0.00100000 | Train Loss: 0.7281 | Val Loss: 6.3281 (Original PGV RMSE: 11.37)
# Epoch [5/100] LR: 0.00100000 | Train Loss: 0.6347 | Val Loss: 5.6809 (Original PGV RMSE: 9.84)
# Epoch [6/100] LR: 0.00100000 | Train Loss: 0.5822 | Val Loss: 99.2947 (Original PGV RMSE: 21260.95)
# Epoch [7/100] LR: 0.00100000 | Train Loss: 0.6268 | Val Loss: 22.4005 (Original PGV RMSE: 112.63)
# Epoch [8/100] LR: 0.00100000 | Train Loss: 0.6091 | Val Loss: 2.8083 (Original PGV RMSE: 4.34)
# Epoch [9/100] LR: 0.00100000 | Train Loss: 0.5460 | Val Loss: 1.5914 (Original PGV RMSE: 2.53)
# Epoch [10/100] LR: 0.00100000 | Train Loss: 0.4965 | Val Loss: 9.8307 (Original PGV RMSE: 22.00)
# Epoch [11/100] LR: 0.00100000 | Train Loss: 0.4780 | Val Loss: 2.6502 (Original PGV RMSE: 4.09)
# Epoch [12/100] LR: 0.00100000 | Train Loss: 0.4654 | Val Loss: 4.9107 (Original PGV RMSE: 8.17)
# Epoch [13/100] LR: 0.00100000 | Train Loss: 0.6144 | Val Loss: 38.0373 (Original PGV RMSE: 475.96)
# Epoch [14/100] LR: 0.00100000 | Train Loss: 0.4991 | Val Loss: 6.3353 (Original PGV RMSE: 11.39)
# Epoch [15/100] LR: 0.00100000 | Train Loss: 0.4230 | Val Loss: 4.1546 (Original PGV RMSE: 6.68)
# Epoch [16/100] LR: 0.00100000 | Train Loss: 0.4193 | Val Loss: 5.6773 (Original PGV RMSE: 9.83)
# Epoch [17/100] LR: 0.00100000 | Train Loss: 0.4681 | Val Loss: 2.4707 (Original PGV RMSE: 3.82)
# Epoch [18/100] LR: 0.00100000 | Train Loss: 0.4638 | Val Loss: 3.5933 (Original PGV RMSE: 5.66)
# Epoch [19/100] LR: 0.00100000 | Train Loss: 0.4486 | Val Loss: 58.0013 (Original PGV RMSE: 2029.14)
# Epoch [20/100] LR: 0.00010000 | Train Loss: 0.5066 | Val Loss: 21.2015 (Original PGV RMSE: 98.93)
# Epoch [21/100] LR: 0.00010000 | Train Loss: 0.4920 | Val Loss: 2.4487 (Original PGV RMSE: 3.78)
# Epoch [22/100] LR: 0.00010000 | Train Loss: 0.3896 | Val Loss: 2.3641 (Original PGV RMSE: 3.65)
# Epoch [23/100] LR: 0.00010000 | Train Loss: 0.5383 | Val Loss: 2.0503 (Original PGV RMSE: 3.19)
# Epoch [24/100] LR: 0.00010000 | Train Loss: 0.5322 | Val Loss: 2.7585 (Original PGV RMSE: 4.26)
# Epoch [25/100] LR: 0.00010000 | Train Loss: 0.5379 | Val Loss: 2.6200 (Original PGV RMSE: 4.05)
# Epoch [26/100] LR: 0.00010000 | Train Loss: 0.4749 | Val Loss: 2.1832 (Original PGV RMSE: 3.38)
# Epoch [27/100] LR: 0.00010000 | Train Loss: 0.5123 | Val Loss: 2.7341 (Original PGV RMSE: 4.23)
# Epoch [28/100] LR: 0.00010000 | Train Loss: 0.5475 | Val Loss: 2.8446 (Original PGV RMSE: 4.40)
# Epoch [29/100] LR: 0.00010000 | Train Loss: 0.3827 | Val Loss: 1.7683 (Original PGV RMSE: 2.78)
# Epoch [30/100] LR: 0.00010000 | Train Loss: 0.3988 | Val Loss: 2.1715 (Original PGV RMSE: 3.36)
# Epoch [31/100] LR: 0.00010000 | Train Loss: 0.3423 | Val Loss: 4.6059 (Original PGV RMSE: 7.55)
# Epoch [32/100] LR: 0.00010000 | Train Loss: 0.4122 | Val Loss: 2.1720 (Original PGV RMSE: 3.37)
# Epoch [33/100] LR: 0.00010000 | Train Loss: 0.3799 | Val Loss: 1.9656 (Original PGV RMSE: 3.06)
# Epoch [34/100] LR: 0.00010000 | Train Loss: 0.4448 | Val Loss: 3.0165 (Original PGV RMSE: 4.68)
# Epoch [35/100] LR: 0.00010000 | Train Loss: 0.4929 | Val Loss: 1.3782 (Original PGV RMSE: 2.23)
# Epoch [36/100] LR: 0.00010000 | Train Loss: 0.4416 | Val Loss: 1.7203 (Original PGV RMSE: 2.71)
# Epoch [37/100] LR: 0.00010000 | Train Loss: 0.3970 | Val Loss: 2.0264 (Original PGV RMSE: 3.15)
# Epoch [38/100] LR: 0.00010000 | Train Loss: 0.4525 | Val Loss: 4.0704 (Original PGV RMSE: 6.52)
# Epoch [39/100] LR: 0.00010000 | Train Loss: 0.4118 | Val Loss: 3.2465 (Original PGV RMSE: 5.06)
# Epoch [40/100] LR: 0.00001000 | Train Loss: 0.4514 | Val Loss: 2.5555 (Original PGV RMSE: 3.95)
# Epoch [41/100] LR: 0.00001000 | Train Loss: 0.4144 | Val Loss: 2.1937 (Original PGV RMSE: 3.40)
# Epoch [42/100] LR: 0.00001000 | Train Loss: 0.4815 | Val Loss: 1.8557 (Original PGV RMSE: 2.90)
# Epoch [43/100] LR: 0.00001000 | Train Loss: 0.4767 | Val Loss: 1.9000 (Original PGV RMSE: 2.97)
# Epoch [44/100] LR: 0.00001000 | Train Loss: 0.5004 | Val Loss: 3.0117 (Original PGV RMSE: 4.67)
# Epoch [45/100] LR: 0.00001000 | Train Loss: 0.4193 | Val Loss: 2.1378 (Original PGV RMSE: 3.32)
# Epoch [46/100] LR: 0.00001000 | Train Loss: 0.3663 | Val Loss: 2.2223 (Original PGV RMSE: 3.44)
# Epoch [47/100] LR: 0.00001000 | Train Loss: 0.4270 | Val Loss: 2.8393 (Original PGV RMSE: 4.39)
# Epoch [48/100] LR: 0.00001000 | Train Loss: 0.4760 | Val Loss: 1.5818 (Original PGV RMSE: 2.52)
# Epoch [49/100] LR: 0.00001000 | Train Loss: 0.3527 | Val Loss: 2.0870 (Original PGV RMSE: 3.24)
# Epoch [50/100] LR: 0.00001000 | Train Loss: 0.4024 | Val Loss: 1.5705 (Original PGV RMSE: 2.50)
# Epoch [51/100] LR: 0.00001000 | Train Loss: 0.4838 | Val Loss: 2.5180 (Original PGV RMSE: 3.89)
# Epoch [52/100] LR: 0.00001000 | Train Loss: 0.4101 | Val Loss: 1.8103 (Original PGV RMSE: 2.84)
# Epoch [53/100] LR: 0.00001000 | Train Loss: 0.4498 | Val Loss: 1.6646 (Original PGV RMSE: 2.63)
# Epoch [54/100] LR: 0.00001000 | Train Loss: 0.3981 | Val Loss: 1.9167 (Original PGV RMSE: 2.99)
# Epoch [55/100] LR: 0.00001000 | Train Loss: 0.4935 | Val Loss: 2.3759 (Original PGV RMSE: 3.67)
# Epoch [56/100] LR: 0.00001000 | Train Loss: 0.4296 | Val Loss: 2.1590 (Original PGV RMSE: 3.35)
# Epoch [57/100] LR: 0.00001000 | Train Loss: 0.4780 | Val Loss: 2.2162 (Original PGV RMSE: 3.43)
# Epoch [58/100] LR: 0.00001000 | Train Loss: 0.4529 | Val Loss: 1.6970 (Original PGV RMSE: 2.68)
# Epoch [59/100] LR: 0.00001000 | Train Loss: 0.5542 | Val Loss: 2.1780 (Original PGV RMSE: 3.37)
# Epoch [60/100] LR: 0.00000100 | Train Loss: 0.5065 | Val Loss: 2.8303 (Original PGV RMSE: 4.38)
# Epoch [61/100] LR: 0.00000100 | Train Loss: 0.4190 | Val Loss: 1.2476 (Original PGV RMSE: 2.06)
# Epoch [62/100] LR: 0.00000100 | Train Loss: 0.4381 | Val Loss: 2.9995 (Original PGV RMSE: 4.65)
# Epoch [63/100] LR: 0.00000100 | Train Loss: 0.4302 | Val Loss: 3.1735 (Original PGV RMSE: 4.94)
# Epoch [64/100] LR: 0.00000100 | Train Loss: 0.4425 | Val Loss: 2.0523 (Original PGV RMSE: 3.19)
# Epoch [65/100] LR: 0.00000100 | Train Loss: 0.4230 | Val Loss: 1.9859 (Original PGV RMSE: 3.09)
# Epoch [66/100] LR: 0.00000100 | Train Loss: 0.4627 | Val Loss: 1.6457 (Original PGV RMSE: 2.61)
# Epoch [67/100] LR: 0.00000100 | Train Loss: 0.4434 | Val Loss: 2.0016 (Original PGV RMSE: 3.12)
# Epoch [68/100] LR: 0.00000100 | Train Loss: 0.3154 | Val Loss: 3.5142 (Original PGV RMSE: 5.52)
# Epoch [69/100] LR: 0.00000100 | Train Loss: 0.4348 | Val Loss: 1.5605 (Original PGV RMSE: 2.49)
# Epoch [70/100] LR: 0.00000100 | Train Loss: 0.3679 | Val Loss: 1.5527 (Original PGV RMSE: 2.48)
# Epoch [71/100] LR: 0.00000100 | Train Loss: 0.4397 | Val Loss: 1.4234 (Original PGV RMSE: 2.30)
# Epoch [72/100] LR: 0.00000100 | Train Loss: 0.4334 | Val Loss: 2.2637 (Original PGV RMSE: 3.50)
# Epoch [73/100] LR: 0.00000100 | Train Loss: 0.4339 | Val Loss: 1.4747 (Original PGV RMSE: 2.37)
# Epoch [74/100] LR: 0.00000100 | Train Loss: 0.4609 | Val Loss: 1.7814 (Original PGV RMSE: 2.80)
# Epoch [75/100] LR: 0.00000100 | Train Loss: 0.4301 | Val Loss: 1.4502 (Original PGV RMSE: 2.33)
# Epoch [76/100] LR: 0.00000100 | Train Loss: 0.3305 | Val Loss: 1.7881 (Original PGV RMSE: 2.81)
# Epoch [77/100] LR: 0.00000100 | Train Loss: 0.3793 | Val Loss: 3.1978 (Original PGV RMSE: 4.98)
# Epoch [78/100] LR: 0.00000100 | Train Loss: 0.4256 | Val Loss: 1.7168 (Original PGV RMSE: 2.71)
# Epoch [79/100] LR: 0.00000100 | Train Loss: 0.4203 | Val Loss: 1.9633 (Original PGV RMSE: 3.06)
# Epoch [80/100] LR: 0.00000100 | Train Loss: 0.3965 | Val Loss: 3.0531 (Original PGV RMSE: 4.74)
# Epoch [81/100] LR: 0.00000100 | Train Loss: 0.3965 | Val Loss: 1.8172 (Original PGV RMSE: 2.85)
# Epoch [82/100] LR: 0.00000100 | Train Loss: 0.4746 | Val Loss: 1.8281 (Original PGV RMSE: 2.87)
# Epoch [83/100] LR: 0.00000100 | Train Loss: 0.4993 | Val Loss: 2.5663 (Original PGV RMSE: 3.96)
# Epoch [84/100] LR: 0.00000100 | Train Loss: 0.4087 | Val Loss: 1.9697 (Original PGV RMSE: 3.07)
# Epoch [85/100] LR: 0.00000100 | Train Loss: 0.3946 | Val Loss: 2.5647 (Original PGV RMSE: 3.96)
# Epoch [86/100] LR: 0.00000100 | Train Loss: 0.3745 | Val Loss: 2.5326 (Original PGV RMSE: 3.91)
# Epoch [87/100] LR: 0.00000100 | Train Loss: 0.3914 | Val Loss: 1.8548 (Original PGV RMSE: 2.90)
# Epoch [88/100] LR: 0.00000100 | Train Loss: 0.4861 | Val Loss: 2.2963 (Original PGV RMSE: 3.55)
# Epoch [89/100] LR: 0.00000100 | Train Loss: 0.4097 | Val Loss: 2.3049 (Original PGV RMSE: 3.56)
# Epoch [90/100] LR: 0.00000010 | Train Loss: 0.4227 | Val Loss: 1.7086 (Original PGV RMSE: 2.70)
# Epoch [91/100] LR: 0.00000010 | Train Loss: 0.3976 | Val Loss: 3.3342 (Original PGV RMSE: 5.21)
# Epoch [92/100] LR: 0.00000010 | Train Loss: 0.4127 | Val Loss: 2.3640 (Original PGV RMSE: 3.65)
# Epoch [93/100] LR: 0.00000010 | Train Loss: 0.4219 | Val Loss: 2.1764 (Original PGV RMSE: 3.37)
# Epoch [94/100] LR: 0.00000010 | Train Loss: 0.4381 | Val Loss: 1.9912 (Original PGV RMSE: 3.10)
# Epoch [95/100] LR: 0.00000010 | Train Loss: 0.4071 | Val Loss: 1.6949 (Original PGV RMSE: 2.68)
# Epoch [96/100] LR: 0.00000010 | Train Loss: 0.3950 | Val Loss: 2.3172 (Original PGV RMSE: 3.58)
# Epoch [97/100] LR: 0.00000010 | Train Loss: 0.3835 | Val Loss: 1.7299 (Original PGV RMSE: 2.73)
# Epoch [98/100] LR: 0.00000010 | Train Loss: 0.4350 | Val Loss: 1.4465 (Original PGV RMSE: 2.33)
# Epoch [99/100] LR: 0.00000010 | Train Loss: 0.3926 | Val Loss: 2.2038 (Original PGV RMSE: 3.41)
# Epoch [100/100] LR: 0.00000010 | Train Loss: 0.4461 | Val Loss: 2.1252 (Original PGV RMSE: 3.30)

# %% [markdown]
# ### Best model 결과 시각화

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.utils.data import DataLoader, random_split

full_dataset = Dataset(pgv_path, seismic_path, is_train=False)

total_size = len(full_dataset)
train_size = int(total_size * 0.8)
val_size = total_size - train_size

torch.manual_seed(42)
_, val_subset = random_split(full_dataset, [train_size, val_size])

val_subset.dataset.is_train = False
val_loader = DataLoader(val_subset, batch_size=8, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_model = FullEQTModel().to(device)
best_model.load_state_dict(torch.load('best_seismic_model.pth'))

def plot_best_model_predictions(model, val_loader, device):
    model.eval()

    actuals = []
    predictions = []

    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)

            actuals.extend(targets.cpu().numpy().flatten())
            predictions.extend(outputs.cpu().numpy().flatten())

    # Log -> Original Scale
    actuals_original = np.expm1(np.array(actuals))
    predictions_original = np.expm1(np.array(predictions))

    # 그래프
    plt.figure(figsize=(10, 10))
    plt.scatter(actuals_original, predictions_original, alpha=0.5, color='dodgerblue', edgecolor='k', s=50)

    max_val = 80
    plt.plot([0, max_val], [0, max_val], color='red', linestyle='--', linewidth=2, label='Perfect Prediction (y=x)')
    plt.plot([0, max_val], [10, max_val + 10], color='gray', linestyle=':', alpha=0.7, label='+10 Error')
    plt.plot([0, max_val], [-10, max_val - 10], color='gray', linestyle=':', alpha=0.7, label='-10 Error')

    plt.title('Best Model: Actual PGV vs Predicted PGV (Original Scale)', fontsize=16, fontweight='bold', pad=15)
    plt.xlabel('Actual PGV', fontsize=14)
    plt.ylabel('Predicted PGV', fontsize=14)

    plt.xlim(0, max_val)
    plt.ylim(0, max_val)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend(fontsize=12)
    plt.tight_layout()
    plt.show()

plot_best_model_predictions(best_model, val_loader, device)

# %% [markdown]
# ### 하이퍼파라미터튜닝

# %%
full_dataset = Dataset(pgv_path, seismic_path, is_train=False)

total_size = len(full_dataset)
train_size = int(total_size * 0.8)
val_size = total_size - train_size

torch.manual_seed(42)
train_subset, val_subset = random_split(full_dataset, [train_size, val_size])

train_subset.dataset.is_train = True
val_subset.dataset.is_train = False

def objective(trial):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    lr = trial.suggest_float("lr", 1e-4, 1e-2, log=True) # 학습률 (로그 스케일 탐색)
    weight_decay = trial.suggest_float("weight_decay", 1e-6, 1e-3, log=True) # 정규화 강도
    optimizer_name = trial.suggest_categorical("optimizer", ["Adam", "AdamW"]) # 옵티마이저 종류
    batch_size = trial.suggest_categorical("batch_size", [4, 8, 16]) # 배치 사이즈

    # 데이터로더 생성 (뽑힌 배치 사이즈 적용)
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)

    # 모델 초기화
    model = FullEQTModel().to(device)
    criterion = nn.MSELoss()

    # 뽑힌 옵티마이저 적용
    if optimizer_name == "Adam":
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    else:
        optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    # 스케줄러 (검증 오차가 안 줄어들면 학습률을 낮추는 스케줄러)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

    TUNE_EPOCHS = 30
    best_val_rmse = float('inf')

    # 학습 루프
    for epoch in range(TUNE_EPOCHS):
        model.train()
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                val_loss += loss.item()

        avg_val_loss = val_loss / len(val_loader)
        val_rmse_original = np.expm1(avg_val_loss ** 0.5)

        # 스케줄러 업데이트
        scheduler.step(avg_val_loss)

        # 현재까지 최고 성능 기록
        if val_rmse_original < best_val_rmse:
            best_val_rmse = val_rmse_original

        # 가망이 없는 조합은 중간에 훈련을 강제 종료
        trial.report(val_rmse_original, epoch)
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    # 최종적으로 이 하이퍼파라미터 조합이 달성한 최고 RMSE를 반환
    return best_val_rmse

# 방향은 '최소화(minimize)' -> RMSE가 낮을수록 좋음
study = optuna.create_study(direction="minimize", pruner=optuna.pruners.MedianPruner())

# 총 20개의 서로 다른 조합을 테스트
study.optimize(objective, n_trials=20)

print("==================================================")
print(f"최고 성능(Val RMSE): {study.best_value:.4f}")
print("최적의 하이퍼파라미터 조합:")
for key, value in study.best_trial.params.items():
    print(f"    - {key}: {value}")
print("==================================================")
# Out:
# [I 2026-03-21 09:57:20,067] A new study created in memory with name: no-name-6136edac-03f4-41a4-9cda-f32129e47ae5
# [I 2026-03-21 10:00:29,265] Trial 0 finished with value: 0.7968724165364623 and parameters: {'lr': 0.0005978530935061044, 'weight_decay': 2.2063407966351052e-05, 'optimizer': 'AdamW', 'batch_size': 16}. Best is trial 0 with value: 0.7968724165364623.
# [I 2026-03-21 10:03:54,820] Trial 1 finished with value: 0.8177884046590876 and parameters: {'lr': 0.0005922080230135517, 'weight_decay': 4.8567512695905605e-05, 'optimizer': 'AdamW', 'batch_size': 8}. Best is trial 0 with value: 0.7968724165364623.
# [I 2026-03-21 10:07:01,861] Trial 2 finished with value: 2.313463705701644 and parameters: {'lr': 0.00013929030672633924, 'weight_decay': 7.906105284534428e-05, 'optimizer': 'Adam', 'batch_size': 16}. Best is trial 0 with value: 0.7968724165364623.
# [I 2026-03-21 10:10:11,025] Trial 3 finished with value: 2.952577569891549 and parameters: {'lr': 0.00011315015889444591, 'weight_decay': 0.0003993348481486963, 'optimizer': 'Adam', 'batch_size': 16}. Best is trial 0 with value: 0.7968724165364623.
# [I 2026-03-21 10:13:34,202] Trial 4 finished with value: 1.1875245572964708 and parameters: {'lr': 0.0004992878012382101, 'weight_decay': 1.2818162315790879e-05, 'optimizer': 'AdamW', 'batch_size': 4}. Best is trial 0 with value: 0.7968724165364623.
# [I 2026-03-21 10:13:41,582] Trial 5 pruned.
# [I 2026-03-21 10:17:05,182] Trial 6 finished with value: 0.5033907222705193 and parameters: {'lr': 0.0004116854701669497, 'weight_decay': 0.0004605802380946597, 'optimizer': 'AdamW', 'batch_size': 4}. Best is trial 6 with value: 0.5033907222705193.
# [I 2026-03-21 10:20:25,922] Trial 7 finished with value: 1.1166441599686396 and parameters: {'lr': 0.002132062847557295, 'weight_decay': 3.054768057957315e-06, 'optimizer': 'AdamW', 'batch_size': 8}. Best is trial 6 with value: 0.5033907222705193.
# [I 2026-03-21 10:20:32,956] Trial 8 pruned.
# [I 2026-03-21 10:20:38,621] Trial 9 pruned.
# [I 2026-03-21 10:20:46,183] Trial 10 pruned.
# [I 2026-03-21 10:24:15,219] Trial 11 finished with value: 0.9643620108100436 and parameters: {'lr': 0.00028919648031068394, 'weight_decay': 1.2398562870639569e-05, 'optimizer': 'AdamW', 'batch_size': 4}. Best is trial 6 with value: 0.5033907222705193.
# [I 2026-03-21 10:24:22,159] Trial 12 pruned.
# [I 2026-03-21 10:24:28,289] Trial 13 pruned.
# [I 2026-03-21 10:24:35,712] Trial 14 pruned.
# [I 2026-03-21 10:24:41,623] Trial 15 pruned.
# [I 2026-03-21 10:24:49,171] Trial 16 pruned.
# [I 2026-03-21 10:28:15,914] Trial 17 finished with value: 1.6350641193159707 and parameters: {'lr': 0.0012926773568893183, 'weight_decay': 0.0001021708881893007, 'optimizer': 'AdamW', 'batch_size': 4}. Best is trial 6 with value: 0.5033907222705193.
# [I 2026-03-21 10:28:23,068] Trial 18 pruned.
# [I 2026-03-21 10:28:29,227] Trial 19 pruned.
# ==================================================
# 최고 성능(Val RMSE): 0.5034
# 최적의 하이퍼파라미터 조합:
#     - lr: 0.0004116854701669497
#     - weight_decay: 0.0004605802380946597
#     - optimizer: AdamW
#     - batch_size: 4
# ==================================================
